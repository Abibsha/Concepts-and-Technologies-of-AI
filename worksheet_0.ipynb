# %% [markdown]
# <a href="https://colab.research.google.com/github/Abibsha/Concepts-and-Technologies-of-AI/blob/main/worksheet_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **7.1**	Warming Up Exercise:
#
# Daily time (in hours): [study, entertainment, sleep] time_data = [
# (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
# (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
# (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
# (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
# (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
# ]
#
# **Task 1.** Classify Study Time:
#
# 1.	Create empty lists for study time classifications:
# (a)	Low: less than 3 hours.
# (b)	Moderate: between 3 and 5 hours.
# (c)	High: more than 5 hours.
# 2.	Iterate over the time_data list and add each study hour to the appropriate category.
# 3.	Print the lists to verify the classifications.

# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %%
low=[]
moderate=[]
high=[]

for i in time_data:
    if (i[0]<3.0):
        low.append(i)
    elif (i[0]<5.0):
        moderate.append(i)
    else:
        high.append(i)

print("For low time schedule of study, entertainment and sleep follow according to given time:\n",low)
print("For moderate time schedule of study, entertainment and sleep follow according to given time:\n",moderate)
print("For high time schedule of study, entertainment and sleep follow according to given time:\n",high)
# Out:
# For low time schedule of study, entertainment and sleep follow according to given time:
#  [(2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0)]
# For moderate time schedule of study, entertainment and sleep follow according to given time:
#  [(3.5, 2.0, 7.0), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (3.5, 2.5, 7.0)]
# For high time schedule of study, entertainment and sleep follow according to given time:
#  [(5.0, 1.5, 6.5), (5.5, 1.0, 6.0), (6.0, 1.5, 6.0), (5.0, 2.0, 6.5)]

# %% [markdown]
# **Task 2.** Based on Data – Answer all the Questions:
# 1. How many days had low study time?
# (a)	Hint: Count the number of items in the low study list and print the result.
# 2.	How many days had moderate study time?
# 3.	How many days had high study time?

# %%
low_count=len(low)
moderate_count=len(moderate)
high_count=len(high)

print(f"The number of days that had low study time is {low_count}.\n"
      f"The number of days that had moderate study time is {moderate_count}.\n"
      f"The number of days that had high study time is {high_count}.\n")
# Out:
# The number of days that had low study time is 4.
# The number of days that had moderate study time is 7.
# The number of days that had high study time is 4.

# %% [markdown]
# **Task 3.** Convert Study Hours to Minutes:
# Convert each study hour value into minutes and store it in a new list called study_minutes.
# 	Formula:	Minutes = Hours× 60
#
# 1.	Iterate over the time_data list and apply the formula to the study hours.
# 2.	Store the results in the new list.
# 3.	Print the converted values.

# %%
study_minutes=[]
for i in time_data:
    study_minutes.append(i[0]*60)
print("The converted study hour values into minutes are :\n")
count=0
for i in study_minutes:
    if (count==len(study_minutes)-1):
        print(i)
    else:
        print(i,end=", ")
    count=count+1
# Out:
# The converted study hour values into minutes are :
#
# 210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0

# %% [markdown]
# **Task 4.** Analyze Average Time Use:
# Scenario: Each record contains daily hours of study, entertainment, and sleep.
#
# 1.	Create empty lists for study_hours, entertainment_hours, and sleep_hours.
# 2.	Iterate over time_data and extract values into each list.
# 3.	Calculate and print:
#
#   (a)	Average hours spent studying.
#
#   (b)	Average hours spent on entertainment.
#
#   (c)	Average hours spent sleeping.

# %%
study_hours=[]
entertainment_hours=[]
sleep_hours=[]

# %%
for i in time_data:
    study_hours.append(i[0])
    entertainment_hours.append(i[1])
    sleep_hours.append(i[2])

# %%
average_study=sum(study_hours)/len(study_hours)
average_entertainment=sum(entertainment_hours)/len(entertainment_hours)
average_sleep=sum(sleep_hours)/len(sleep_hours)

print(f"The average hours spent on studying is {average_study:.2f}\n"
      f"The average hours spent on entertainment is {average_entertainment:.2f}\n"
      f"The average hours spent on sleeping is {average_sleep:.2f}\n")
# Out:
# The average hours spent on studying is 3.70
# The average hours spent on entertainment is 2.50
# The average hours spent on sleeping is 7.17

# %% [markdown]
# **Task 5.** Visualization - Study vs Sleep Pattern:
#
# 1.	Import matplotlib.pyplot as plt.
# 2.	Plot a scatter plot with:
# •	x-axis: Study hours
# •	y-axis: Sleep hours
# 3. Add labels, title, and color.

# %%
import matplotlib.pyplot as plt

plt.scatter(study_hours,sleep_hours,color="blue")
plt.title("Study vs Sleep Pattern")
plt.xlabel('Study hours')
plt.ylabel('Sleep hours')
plt.grid()
plt.show()

# %% [markdown]
# **8.1.1	Exercise - Recursion:**
#
# **Task 1.** Sum of Nested Lists:
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists). You want to find the total sum of all the numbers in this structure.
#
# • Write a recursive function sum_nested_list(nested_list) that:
#
# 1.	Takes a nested list (a list that can contain numbers or other lists of numbers) as input.
# 2.	Sums all numbers at every depth level of the list, regardless of how deeply nested the numbers are.
# •	Test the function with a sample nested list, such as nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.

# %%
def sum_nested_list(nested_list):
    total=0
    for element in nested_list:
        if isinstance(element,list):
            total+=sum_nested_list(element)
        else:
            total+=element
    return total

list1=[1,[2,3,4],5,7,[8,9]]
list2=[3,5,[10,[9,7],16]]

sum1=sum_nested_list(list1);
sum2=sum_nested_list(list2);

print(sum1,sum2)
# Out:
# 39 50

# %% [markdown]
# **Task 2.** Generate All Permutations of a String:
#
# Scenario: Given a string, generate all possible permutations of its characters. This is useful for understanding backtracking and recursive depth-first search.
#
# •	Write a recursive function generate_permutations(s) that:
#
# • Takes a string s as input and returns a list of all unique permutations.
#
# • Test with strings like ”abc” and ”aab”.
# print(generate_permutations("abc"))
#
#   Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
    if len(s)==1:
        return [s]
    list_of_permutations=[]
    for i in range(len(s)):
        eliminated_char=s[i];
        remaining_string=s[:i]+s[i+1:]
        for j in generate_permutations(remaining_string):
            new_permutation=eliminated_char+j
            if(new_permutation in list_of_permutations):
                continue
            list_of_permutations.append(new_permutation);
    return list_of_permutations

text=str(input("Enter a string: "));
list_of_permutations=[generate_permutations(text)];
print(f"All unique permutations of the string '{text}' are:\n{list_of_permutations}")
# Out:
# Enter a string: bag
# All unique permutations of the string 'bag' are:
# [['bag', 'bga', 'abg', 'agb', 'gba', 'gab']]

# %% [markdown]
# **Task 3.** Directory Size Calculation:
# 1. Write a recursive function calculate_directory_size(directory) where:
#
#    •	directory is a dictionary where keys represent file names (with values as sizes in KB) or directory names (with values as another dictionary representing a subdirectory).
#
#     •	The function should return the total size of the directory, including all nested subdirectories.
#
# 2. Test the function with a sample directory structure.

# %%
def calculate_directory_size(directory):
    total_size=0
    for element in directory.values():
        if isinstance(element,dict):
            total_size+=calculate_directory_size(element)
        else:
            total_size+=element
    return total_size

# %%
# Sample directory structure
directory_structure = {
 "file1.txt": 200,
 "file2.txt": 300,
 "subdir1": {
 "file3.txt": 400,
 "file4.txt": 100
 },
 "subdir2": {
 "subsubdir1": {
 "file5.txt": 250
 },
 "file6.txt": 150
 }
 }

# %%
directory_size=int(calculate_directory_size(directory_structure))
print("The total size of the directory is ",directory_size)
# Out:
# The total size of the directory is  1400

# %% [markdown]
# **8.2.1	Exercises - Dynamic Programming:**
#
# **Task 1.** Coin Change Problem:
#
# Scenario: Given a set of coin denominations and a target amount, find the minimum number of coins needed to make the amount. If it’s not possible, return - 1.
#
# 1.	Write a function min_coins(coins, amount) that:
#
#    • Uses DP to calculate the minimum number of coins needed to make up the amount.
# 2.	Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).

# %%
def min_coins(coins,amount):
    dp=[float('inf')]*(amount+1)
    dp[0]=0
    for coin in coins:
        for i in range(coin,amount+1):
            dp[i]=min(dp[i],dp[i-coin]+1)
    return dp[amount] if dp[amount]!=float('inf')else-1

coins=[1,2,5]
amount=11
num_of_coins_required=min_coins(coins,amount)

print("The minimum number of coins needed to make the amount is ",num_of_coins_required,".")
# Out:
# The minimum number of coins needed to make the amount is  3 .

# %% [markdown]
# **Task 2.** Longest Common Subsequence (LCS):
#
# Scenario: Given two strings, find the length of their longest common subsequence (LCS). This is useful in text comparison.
#
# 1.	Write a function longest_common_subsequence(s1, s2) that:
#
#   • Uses DP to find the length of the LCS of two strings s1 and s2.
# 2.	Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
def longest_common_subsequence(s1, s2):
    m,n=len(s1),len(s2)
    dp= [[""]*(n+1) for i in range(m+1)]
    for i in range(m):
        for j in range(n):
            if s1[i]==s2[j]:
                dp[i+1][j+1]=dp[i][j]+s1[i]
            else:
                if len(dp[i][j+1])>len(dp[i+1][j]):
                    dp[i+1][j+1]=dp[i][j+1]
                else:
                    dp[i+1][j+1]=dp[i+1][j]
    return dp[m][n]

# %%
s1="abcde"
s2="ace"
LCS=longest_common_subsequence(s1,s2)
print(f"The LCS in the strings {s1} and {s2} is {LCS}.")
# Out:
# The LCS in the strings abcde and ace is ace.

# %% [markdown]
# **Task 3.** 0/1 Knapsack Problem:
#
# Scenario: You have a list of items, each with a weight and a value. Given a weight capacity, maximize the total value of items you can carry without exceeding the weight capacity.
#
# 1.	Write a function knapsack(weights, values, capacity) that:
#
#   • Uses DP to determine the maximum value that can be achieved within the given weight capacity.
# 2.	Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The result should be 9.

# %%
def knapsack(weights, values, capacity):
    n=len(weights)
    dp=[[0]*(capacity+1) for i in range(n+1)]
    for i in range(1,n+1):
        for w in range(1,capacity+1):
            if weights[i-1]<=w:
                dp[i][w]=max(dp[i-1][w],dp[i-1][w-weights[i-1]]+values[i-1])
            else:
                dp[i][w]=dp[i-1][w]
    return dp[n][capacity]

# %%
weights=[1,3,4,5]
values=[1,4,5,7]
capacity=7

capacity_of_weight=(knapsack(weights,values,capacity))

print("The maximum value that can be achieved is ",capacity_of_weight)
# Out:
# The maximum value that can be achieved is  9
